# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *
plt.xkcd()

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.xticks([])
plt.yticks([])
ax.set_ylim([-30, 10])

data = np.ones(1000)
data[700:] -= np.arange(300)

plt.annotate(
    'SHARP DROP IQ,\nNO REASON\nWHATSOEVER',
    xy=(700, .3), arrowprops=dict(arrowstyle='->'), xytext=(15, -10))

plt.plot(data)
plt.text(-100, -36, "Tyrion")
plt.xlabel('Time')
plt.ylabel("IQ level")

# %%
plt.plot([0, 1, 1.5, 1.7, 2.1], [0, 4, 4, 6, 0], linestyle='-')


plt.xticks([])
plt.yticks([])

plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')

plt.annotate(
    'PUBERTY',
    xy=(1, 4), arrowprops=dict(arrowstyle='->'), xytext=(.5, 5))

plt.annotate(
    'Ygritte+cave',
    xy=(1.7, 6), arrowprops=dict(arrowstyle='->'), xytext=(1.5, 7))

plt.annotate(
    "YoU r mY qUeEn",
    xy=(2.1, 0), arrowprops=dict(arrowstyle='->'), xytext=(1.1, 1))

plt.xlabel('Time')
plt.ylabel("Testosterone level")
plt.text(-.2, -1.5, "Jon")

# %%
xarray = [0, 100]
yarray = [0, 100]
plt.plot(xarray, yarray, linestyle='-')


plt.xticks([])
plt.yticks([])

plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')


plt.annotate(
    "The only character development\nthat made sense and\nwas consistent",
    xy=(2.1, 0),  xytext=(13, 70))
plt.annotate(
    "Naive af",
    xy=(0,0),  xytext=(-25,0))
plt.annotate(
    "Woke af",
    xy=(100,100),  xytext=(-25,99))


plt.xlabel('Time')


plt.text(-10, -25, "Sansa")

# %%
from scipy.interpolate import make_interp_spline, BSpline
xarray = np.array([12, 11, 10, 9, 8, 7, 6])
#yarray = np.array([1.53E+03, 5.92E+02, 2.04E+02, 7.24E+01, 2.72E+01, 1.10E+01, 4.70E+00])
#yarray = np.array([4.70E+00, 1.10E+01, 2.72E+01, 7.24E+01, 2.04E+02, 5.92E+02, 1.53E+03,])
yarray = np.array([12, 11, 10, 9, 8, 7, 6])
#plt.plot(xarray, yarray, linestyle='-')


plt.xticks([])
plt.yticks([])

plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')

xnew = np.linspace(xarray.min(),xarray.max(),300)
spl = make_interp_spline(xarray, yarray, k=3) #Bspline object
power_smooth = spl(xnew)
plt.plot(xnew,power_smooth)

plt.xlabel('Time')
plt.ylabel("Mad queen index")
plt.text(-0, -2, "Dany")
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-240-09b0281c38c8> in <module>()
#      14
#      15 xnew = np.linspace(xarray.min(),xarray.max(),300)
# ---> 16 spl = make_interp_spline(xarray, yarray, k=3) #Bspline object
#      17 power_smooth = spl(xnew)
#      18 plt.plot(xnew,power_smooth)
#
# C:\Users\janeo\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\scipy\interpolate\_bsplines.py in make_interp_spline(x, y, k, t, bc_type, axis, check_finite)
#     749
#     750     if x.ndim != 1 or np.any(x[1:] <= x[:-1]):
# --> 751         raise ValueError("Expect x to be a 1-D sorted array_like.")
#     752     if k < 0:
#     753         raise ValueError("Expect non-negative k.")
#
# ValueError: Expect x to be a 1-D sorted array_like.
