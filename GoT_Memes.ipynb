# %%
# %matplotlib inline
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
from math import *
plt.xkcd()

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.xticks([])
plt.yticks([])
ax.set_ylim([-30, 10])

data = np.ones(1000)
data[700:] -= np.arange(300)

plt.annotate(
    'SHARP DROP IQ,\nNO REASON\nWHATSOEVER',
    xy=(700, .3), arrowprops=dict(arrowstyle='->'), xytext=(15, -10))

plt.plot(data)
plt.text(-100, -36, "Tyrion")
plt.xlabel('Time')
plt.ylabel("IQ level")

# %%
plt.plot([0, 1, 1.5, 1.7, 2.1], [0, 4, 4, 6, 0], linestyle='-')


plt.xticks([])
plt.yticks([])

plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')

plt.annotate(
    'PUBERTY',
    xy=(1, 4), arrowprops=dict(arrowstyle='->'), xytext=(.5, 5))

plt.annotate(
    'Ygritte+cave',
    xy=(1.7, 6), arrowprops=dict(arrowstyle='->'), xytext=(1.5, 7))

plt.annotate(
    "YoU r mY qUeEn",
    xy=(2.1, 0), arrowprops=dict(arrowstyle='->'), xytext=(1.1, 1))

plt.xlabel('Time')
plt.ylabel("Testosterone level")
plt.text(-.2, -1.5, "Jon")

# %%
xarray = [0, 100]
yarray = [0, 100]
plt.plot(xarray, yarray, linestyle='-')


plt.xticks([])
plt.yticks([])

plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')


plt.annotate(
    "The only character development\nthat made sense and\nwas consistent",
    xy=(2.1, 0),  xytext=(13, 70))
plt.annotate(
    "Naive af -",
    xy=(0,0),  xytext=(-25,0))
plt.annotate(
    "Woke af -",
    xy=(100,100),  xytext=(-25,99))


plt.xlabel('Time')

plt.text(-10, -25, "Sansa")

# %%
import numpy as np
plt.xticks([])
plt.yticks([])
plt.gca().spines['right'].set_color('none')
plt.gca().spines['top'].set_color('none')

x1 = np.array(range(100))
y1 = x1 ** .5
plt.plot(x1, y1, linewidth=3)

x2 = np.array(range(20))
y2 = x2 **.5
plt.plot(x2, y2, markerfacecolor='red' , linewidth=0.8)

x3 = xlim(20,50)
y3 = 4.472135955
plt.plot(x3, y3)

plt.annotate(
    "What was supposed\n to happen",
    xy=(2.1, 0),  xytext=(25, 9), color='slategray', rotation=25)
plt.xlabel('Time')
plt.ylabel('Mad queen index')
plt.text(-11, -2.5, "Dany")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-104-44bd4bf30d9b> in <module>()
#      15
#      16 y3 = 4.472135955
# ---> 17 plt.plot(xlim(20,50), y3)
#      18
#      19 plt.annotate(
#
# NameError: name 'xlim' is not defined
